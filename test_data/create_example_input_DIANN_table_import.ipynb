# %%
import pandas as pd

df_test = pd.read_csv("../DIANN/Ref0s4s8_report.tsv", sep="\t")
df_test.set_index("Protein.Group", inplace=True)

proteins_selected = df_test.index.unique()[:50]
df_test = df_test.loc[proteins_selected]
display(df_test)
# Out:
#                                                        File.Name  \
# Protein.Group
# P37108         D:\MCT\Collaborations\multiplexing\singleCell\...
# P37108         D:\MCT\Collaborations\multiplexing\singleCell\...
# P37108         D:\MCT\Collaborations\multiplexing\singleCell\...
# P37108         D:\MCT\Collaborations\multiplexing\singleCell\...
# P37108         D:\MCT\Collaborations\multiplexing\singleCell\...
# ...                                                          ...
# Q86VP6         D:\MCT\Collaborations\multiplexing\singleCell\...
# Q86VP6         D:\MCT\Collaborations\multiplexing\singleCell\...
# Q86VP6         D:\MCT\Collaborations\multiplexing\singleCell\...
# Q86VP6         D:\MCT\Collaborations\multiplexing\singleCell\...
# Q86VP6         D:\MCT\Collaborations\multiplexing\singleCell\...
#
#                                                              Run  \
# Protein.Group
# P37108         20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
# ...

# %%
display(df_test.index.unique())
# Out:
# Index(['P37108', 'Q9Y4H2', 'P36578', 'O76031', 'Q8WUQ7;Q8WUQ7-2', 'A6NIH7',
#        'Q9P258', 'Q68DK7', 'A1X283', 'O60346', 'Q9BQE4', 'Q8WWH5', 'Q9UNF1',
#        'Q9NQP4', 'O15357', 'P02786', 'P07954;P07954-2', 'Q9Y490', 'O94826',
#        'Q96S52', 'Q9GZT9', 'Q96T51', 'Q5VSL9', 'O14497;O14497-2', 'P58107',
#        'Q8TAE8', 'P31948;P31948-2', 'Q14498;Q14498-2;Q14498-3', 'Q9NX63',
#        'P31350;P31350-2', 'Q16643;Q16643-2;Q16643-3', 'Q9NVA2;Q9NVA2-2',
#        'O14981', 'O95801', 'P08559;P08559-2;P08559-3;P08559-4',
#        'Q99733;Q99733-2', 'Q8N1S5;Q8N1S5-2', 'Q03252', 'P49006', 'P19404',
#        'O43837', 'P13995', 'P49585', 'Q9H7E9;Q9H7E9-2', 'P06753',
#        'Q14980;Q14980-2', 'Q9UNF0', 'Q6P1J9', 'P51452', 'Q86VP6'],
#       dtype='object', name='Protein.Group')

# %%
df_test.to_csv("diann_test_input.tsv", sep="\t", index=True)
