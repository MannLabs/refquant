# %%
import pandas as pd

df_test = pd.read_csv("../spectronaut_library_tests/benchmark_filter_3_6/M07_labelW_filter_3_6_Report.tsv", sep="\t")
df_test.set_index("PG.ProteinGroups", inplace=True)

proteins_selected = df_test.index.unique()[:50]
df_test = df_test.loc[proteins_selected]
display(df_test)
# Out:
#                                                              R.Label  \
# PG.ProteinGroups
# A0A0B4J2D5;P0DPI2  20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
# A0A0B4J2D5;P0DPI2  20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
# A0A0B4J2D5;P0DPI2  20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
# A0A0B4J2D5;P0DPI2  20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
# A0A0B4J2D5;P0DPI2  20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
# ...                                                              ...
# O00469;O00469-2    20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
# O00469;O00469-2    20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
# O00469;O00469-2    20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
# O00469;O00469-2    20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
# O00469;O00469-2    20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...
#
#                        PG.Genes  PG.Organisms  PG.Quantity  \
# PG.ProteinGroups
# ...

# %%
df_test.to_csv("spectronaut_test_input.tsv", sep="\t", index=True)
