# %%
import sys
sys.path.append("../refquant")
import table_import
test_input = "../test_data/spectronaut_test_input.tsv"
output_generated_w_different_implementation = "../test_data/output_file_generated_w_different_implementation.tsv"

# %%
import pandas as pd
display(pd.read_csv(test_input, sep="\t").columns)
# Out:
# Index(['PG.ProteinGroups', 'R.Label', 'PG.Genes', 'PG.Organisms',
#        'PG.Quantity', 'PEP.NrOfMissedCleavages', 'PEP.MS1ChannelQuantities',
#        'PEP.MS2ChannelQuantities', 'PEP.StrippedSequence',
#        'EG.PeakWidth (iRT)', 'PEP.MS1Quantity', 'PEP.MS2Quantity',
#        'PEP.Quantity', 'PEP.UsedForProteinGroupQuantity', 'EG.IsDecoy',
#        'EG.ModifiedSequence', 'EG.PEP', 'EG.Pvalue', 'EG.Qvalue', 'EG.Svalue',
#        'EG.ApexRT', 'EG.DatapointsPerPeak', 'EG.DeltaRT', 'EG.FWHM (iRT)',
#        'EG.MeanTailingFactor', 'EG.RTPredicted', 'EG.SignalToNoise',
#        'EG.AvgProfileQvalue', 'EG.MaxProfileQvalue', 'EG.MinProfileQvalue',
#        'EG.PercentileQvalue', 'EG.IsImputed',
#        'EG.ReferenceQuantity (Settings)', 'EG.TargetQuantity (Settings)',
#        'EG.TotalQuantity (Settings)', 'EG.UsedForPeptideQuantity',
#        'EG.UsedForProteinGroupQuantity', 'EG.Cscore', 'EG.IntCorrScore',
#        'EG.Noise', 'FG.Charge', 'FG.FragmentCount', 'FG.Id', 'FG.Label',
#        'FG.PrecMz', 'FG.Reference', 'FG.PrecursorSignalToNoise',
#        'FG.SignalToNoise', 'FG.ShapeQualityScore',
#        'FG.MS1IsotopeIntensities (Measured)', 'FG.MS1IsotopeQuantity',
#        'FG.MS1RawQuantity', 'FG.MS2RawQuantity',
#        'FG.HasPossibleInterference (MS1)', 'FG.HasPossibleInterference (MS2)',
#        'FG.Quantity', 'FG.ReporterIons', 'FG.CalibratedMassAccuracy (PPM)',
#        'FG.PPMTolerance', 'FG.Tolerance', 'F.Charge', 'F.FrgIon',
#        'F.FrgLossType', 'F.Rank', 'F.ExcludedFromQuantification', 'F.PeakArea',
#        'F.PeakHeight', 'F.CalibratedMassAccuracy (PPM)',
#        'F.HasChannelInterference', 'F.InterferenceScore',
#        'F.Log10SignalToNoise', 'F.Noise', 'F.PossibleInterference',
#        'F.PPMTolerance', 'F.RawMassAccuracy (PPM)', 'F.Tolerance'],
#       dtype='object')

# %%
reformatted_table = table_import.TableReformatterSpectronaut(test_input)
# Out:
# using input type spectronaut_precursor_v3
# using input type spectronaut_fragion_isotopes
# using input type spectronaut_precursor_v3
# using input type spectronaut_fragion_isotopes
# using input type spectronaut_precursor_v3
# using input type spectronaut_fragion_isotopes
# ['protein', 'ion', 'precursor', 'run_channel', 'run', 'reference', 'target4', 'target8']

# %%
output_df = reformatted_table.spectronaut_table_reformatted
display(output_df.drop_duplicates())
# Out:
#                                                      run            protein  \
# 0      20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...  A0A0B4J2D5;P0DPI2
# 1      20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...  A0A0B4J2D5;P0DPI2
# 2      20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...  A0A0B4J2D5;P0DPI2
# 3      20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...  A0A0B4J2D5;P0DPI2
# 4      20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...  A0A0B4J2D5;P0DPI2
# ...                                                  ...                ...
# 24395  20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...    O00469;O00469-2
# 24396  20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...    O00469;O00469-2
# 24397  20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...    O00469;O00469-2
# 24398  20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...    O00469;O00469-2
# 24399  20220730_TIMS06_MCT_SA_HeLa_whi40_M07_Ref0s4s8...    O00469;O00469-2
#
#                                                precursor  \
# 0      SEQ_NLSTFAVDGK_MOD__[DimethNter0]NLSTFAVDGK[Di...
# 1      SEQ_NLSTFAVDGK_MOD__[DimethNter0]NLSTFAVDGK[Di...
# 2      SEQ_NLSTFAVDGK_MOD__[DimethNter0]NLSTFAVDGK[Di...
# 3      SEQ_NLSTFAVDGK_MOD__[DimethNter0]NLSTFAVDGK[Di...
# 4      SEQ_NLSTFAVDGK_MOD__[DimethNter0]NLSTFAVDGK[Di...
# ...                                                  ...
# 24395  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 24396  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 24397  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 24398  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 24399  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
#
#                                                      ion     reference  \
# 0      SEQ_NLSTFAVDGK_MOD__[DimethNter0]NLSTFAVDGK[Di...   2473.021240
# 1      SEQ_NLSTFAVDGK_MOD__[DimethNter0]NLSTFAVDGK[Di...    602.312134
# 2      SEQ_NLSTFAVDGK_MOD__[DimethNter0]NLSTFAVDGK[Di...    496.287598
# 3      SEQ_NLSTFAVDGK_MOD__[DimethNter0]NLSTFAVDGK[Di...   1051.502930
# 4      SEQ_NLSTFAVDGK_MOD__[DimethNter0]NLSTFAVDGK[Di...    443.985962
# ...                                                  ...           ...
# 24395  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...     88.878075
# 24396  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  22029.000000
# 24397  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  13650.000000
# 24398  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  12860.000000
# 24399  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...   9745.000000
#
#             target4      target8
# 0          0.000000     0.000000
# 1          0.000000     0.000000
# 2          0.000000     0.000000
# 3          0.000000     0.000000
# 4          0.000000     0.000000
# ...             ...          ...
# 24395    142.715561     5.302744
# 24396  10722.000000  7789.000000
# 24397  12502.000000  4213.000000
# 24398   6305.000000  6357.000000
# 24399   9739.000000  8285.000000
#
# [24400 rows x 7 columns]

# %%
import pandas as pd

comparison_df = pd.read_csv(output_generated_w_different_implementation, sep = "\t")
display(comparison_df)
# Out:
#       replicate          protein  \
# 0          3970           A0AVT1
# 1          3970         A0FGR8-2
# 2          3970         A0FGR8-2
# 3          3970  A0MZ66;A0MZ66-3
# 4          3970  A0MZ66;A0MZ66-3
# ...         ...              ...
# 7565       3979  O00469;O00469-2
# 7566       3979  O00469;O00469-2
# 7567       3979  O00469;O00469-2
# 7568       3979  O00469;O00469-2
# 7569       3979  O00469;O00469-2
#
#                                               precursor  \
# 0     SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...
# 1     SEQ_ALALLEDEER_MOD__[DimethNter0]ALALLEDEER__C...
# 2     SEQ_AQPPEAGPQGLHDLGR_MOD__[DimethNter0]AQPPEAG...
# 3     SEQ_LTQQLEEER_MOD__[DimethNter0]LTQQLEEER__CHA...
# 4     SEQ_SLDPENSETELER_MOD__[DimethNter0]SLDPENSETE...
# ...                                                 ...
# 7565  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 7566  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 7567  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 7568  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 7569  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
#
#                                                     ion     reference  \
# 0     SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...   2286.740234
# 1     SEQ_ALALLEDEER_MOD__[DimethNter0]ALALLEDEER__C...    426.730560
# 2     SEQ_AQPPEAGPQGLHDLGR_MOD__[DimethNter0]AQPPEAG...    333.435089
# 3     SEQ_LTQQLEEER_MOD__[DimethNter0]LTQQLEEER__CHA...    183.873199
# 4     SEQ_SLDPENSETELER_MOD__[DimethNter0]SLDPENSETE...    415.404449
# ...                                                 ...           ...
# 7565  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...     88.878075
# 7566  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  22029.000000
# 7567  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  13650.000000
# 7568  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  12860.000000
# 7569  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...   9745.000000
#
#            target4      target8
# 0         0.000000  3684.078125
# 1       305.247131     9.454959
# 2       510.888214   708.308472
# 3        41.861946     8.063574
# 4         0.000000    50.559669
# ...            ...          ...
# 7565    142.715561     5.302744
# 7566  10722.000000  7789.000000
# 7567  12502.000000  4213.000000
# 7568   6305.000000  6357.000000
# 7569   9739.000000  8285.000000
#
# [7570 rows x 7 columns]

# %%
import matplotlib_venn as venn
set1 = set(output_df["precursor"])
set2 = set(comparison_df["precursor"])

venn.venn2([set1, set2], set_labels = ("output_df", "comparison_df"))

output_df_reduced = output_df.drop(columns=["run"]).reset_index(drop=True).drop_duplicates()
comparison_df_reduced = comparison_df.drop(columns=["replicate"]).reset_index(drop=True).drop_duplicates()

output_df_intersection_set = set(output_df_reduced["ion"]).intersection(set(comparison_df_reduced["ion"]))

output_df_intersection = output_df_reduced[output_df_reduced["ion"].isin(output_df_intersection_set)]


print(output_df_intersection.equals(comparison_df_reduced))

display(output_df_intersection)
display(comparison_df_reduced)
# Out:
# False
#                protein                                          precursor  \
# 78              A0AVT1  SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...
# 79              A0AVT1  SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...
# 80              A0AVT1  SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...
# 81              A0AVT1  SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...
# 82              A0AVT1  SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...
# ...                ...                                                ...
# 24395  O00469;O00469-2  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 24396  O00469;O00469-2  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 24397  O00469;O00469-2  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 24398  O00469;O00469-2  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 24399  O00469;O00469-2  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
#
#                                                      ion     reference  \
# 78     SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...   2286.740234
# 79     SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...   1004.868469
# 80     SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...    224.580536
# 81     SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...   1497.709351
# 82     SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...  13096.000000
# ...                                                  ...           ...
# 24395  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...     88.878075
# 24396  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  22029.000000
# 24397  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  13650.000000
# 24398  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  12860.000000
# 24399  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...   9745.000000
#
#             target4      target8
# 78         0.000000  3684.078125
# 79         0.000000   896.399963
# 80         0.000000  2733.390381
# 81         0.000000   776.068848
# 82         0.000000  7306.000000
# ...             ...          ...
# 24395    142.715561     5.302744
# 24396  10722.000000  7789.000000
# 24397  12502.000000  4213.000000
# 24398   6305.000000  6357.000000
# 24399   9739.000000  8285.000000
#
# [7321 rows x 6 columns]
#               protein                                          precursor  \
# 0              A0AVT1  SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...
# 1            A0FGR8-2  SEQ_ALALLEDEER_MOD__[DimethNter0]ALALLEDEER__C...
# 2            A0FGR8-2  SEQ_AQPPEAGPQGLHDLGR_MOD__[DimethNter0]AQPPEAG...
# 3     A0MZ66;A0MZ66-3  SEQ_LTQQLEEER_MOD__[DimethNter0]LTQQLEEER__CHA...
# 4     A0MZ66;A0MZ66-3  SEQ_SLDPENSETELER_MOD__[DimethNter0]SLDPENSETE...
# ...               ...                                                ...
# 7565  O00469;O00469-2  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 7566  O00469;O00469-2  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 7567  O00469;O00469-2  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 7568  O00469;O00469-2  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
# 7569  O00469;O00469-2  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...
#
#                                                     ion     reference  \
# 0     SEQ_YYFSHDTD_MOD__[DimethNter0]YYFSHDTD__CHARG...   2286.740234
# 1     SEQ_ALALLEDEER_MOD__[DimethNter0]ALALLEDEER__C...    426.730560
# 2     SEQ_AQPPEAGPQGLHDLGR_MOD__[DimethNter0]AQPPEAG...    333.435089
# 3     SEQ_LTQQLEEER_MOD__[DimethNter0]LTQQLEEER__CHA...    183.873199
# 4     SEQ_SLDPENSETELER_MOD__[DimethNter0]SLDPENSETE...    415.404449
# ...                                                 ...           ...
# 7565  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...     88.878075
# 7566  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  22029.000000
# 7567  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  13650.000000
# 7568  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...  12860.000000
# 7569  SEQ_VLGQGEEWR_MOD__[DimethNter0]VLGQGEEWR__CHA...   9745.000000
#
#            target4      target8
# 0         0.000000  3684.078125
# 1       305.247131     9.454959
# 2       510.888214   708.308472
# 3        41.861946     8.063574
# 4         0.000000    50.559669
# ...            ...          ...
# 7565    142.715561     5.302744
# 7566  10722.000000  7789.000000
# 7567  12502.000000  4213.000000
# 7568   6305.000000  6357.000000
# 7569   9739.000000  8285.000000
#
# [7437 rows x 6 columns]
